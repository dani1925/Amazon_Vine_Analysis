# %%
import pandas as pd
pd_df = pd.read_csv('vine_table.csv')

# %%
total_votes = pd_df.loc[pd_df['total_votes']>=20]
total_votes.head()
# Out:
#          review_id  star_rating  helpful_votes  total_votes vine  \
# 6   R1002I943QCT20            2             21           23    N
# 24  R1009A7Y1S2AYR            5              9           24    N
# 30  R100EDTLBC4CM4            5             20           20    N
# 47  R100NBNVTJ20IT            1             20           29    N
# 84  R101E7LOLK03C1            2             18           20    N
#
#    verified_purchase
# 6                  N
# 24                 N
# 30                 N
# 47                 N
# 84                 Y

# %%
helpf_total = total_votes.loc[total_votes['helpful_votes']  / total_votes['total_votes']>=0.5]
helpf_total.head()
# Out:
#          review_id  star_rating  helpful_votes  total_votes vine  \
# 6   R1002I943QCT20            2             21           23    N
# 30  R100EDTLBC4CM4            5             20           20    N
# 47  R100NBNVTJ20IT            1             20           29    N
# 84  R101E7LOLK03C1            2             18           20    N
# 85  R101EBVZE5MS7R            1             57           57    N
#
#    verified_purchase
# 6                  N
# 30                 N
# 47                 N
# 84                 Y
# 85                 N

# %%
vine_Y = helpf_total.loc[helpf_total['vine']=='Y']
vine_Y.head()
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 5955   R12EV95D2T56HA            5             37           37    Y
# 10722  R14B5QO4LAZTIT            5             20           22    Y
# 11488  R14M63V32IEHDG            4             61           63    Y
# 13877  R15L29557GRCIO            5             57           61    Y
# 16829  R16S2VP97REPC2            4            522          533    Y
#
#       verified_purchase
# 5955                  N
# 10722                 N
# 11488                 N
# 13877                 N
# 16829                 N

# %%
vine_N = helpf_total.loc[helpf_total['vine']=='N']
vine_N.head()
# Out:
#          review_id  star_rating  helpful_votes  total_votes vine  \
# 6   R1002I943QCT20            2             21           23    N
# 30  R100EDTLBC4CM4            5             20           20    N
# 47  R100NBNVTJ20IT            1             20           29    N
# 84  R101E7LOLK03C1            2             18           20    N
# 85  R101EBVZE5MS7R            1             57           57    N
#
#    verified_purchase
# 6                  N
# 30                 N
# 47                 N
# 84                 Y
# 85                 N

# %%
total_reviews = vine_Y['review_id'].count()
print(total_reviews)

total_reviews_N = vine_N['review_id'].count()
print(total_reviews_N)
# Out:
# 248
# 17514

# %%
star_vine_y = vine_Y['star_rating'].loc[vine_Y['star_rating']==5].count()
print(star_vine_y)


star_vine_n = vine_N['star_rating'].loc[vine_N['star_rating']==5].count()
print(star_vine_n)
# Out:
# 102
# 5154

# %%
five_stars_Y = star_vine_y / total_reviews
print(five_stars_Y*100)

five_stars_n = star_vine_n / total_reviews_N
print(five_stars_n*100)
# Out:
# 41.12903225806452
# 29.427886262418635
